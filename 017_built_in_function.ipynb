# %% [markdown]
# ## **Function**
# block of code

# %% [markdown]
# **1. print**

# %%
print("siyam hossain")
# Out:
# siyam hossain

# %% [markdown]
# **2. input**

# %%
input("Enter your name: ")
# Out:
# ''

# %% [markdown]
# **3. type**

# %%
a = 1
b = 2.3
c = "siyam"
d = 's'
e = (1,2,3,4,6)
f = [1,23,45,56,4]
g = {1,23,45,78,7}

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'tuple'>
# <class 'list'>
# <class 'set'>

# %% [markdown]
# **4. int etc.**

# %%
int("5")
# float
# str
# list
# tuple
# Out:
# 5

# %% [markdown]
# **5. abs**

# %%
abs(-4)
# Out:
# 4

# %% [markdown]
# **6. pow**

# %%
pow(2,3)
# Out:
# 8

# %% [markdown]
# **7. min/max**

# %%
print("min: ",min([15,2,0,3,1,45]))
print("max: ",max([15,2,0,3,1,45]))

print(max("siyam hossain"))
# Out:
# min:  0
# max:  45
# y

# %% [markdown]
# **8. round**

# %%
c = 22/7
print(c)

print(round(c))
print(round(c,2))
print(round(c,5))
# Out:
# 3.142857142857143
# 3
# 3.14
# 3.14286

# %% [markdown]
# **9. divmod**

# %%
# 5//2 integer division = 2
# 5%2 = 1
divmod(5,2)
# Out:
# (2, 1)

# %% [markdown]
# **10. bin/oct/hex**

# %%
print(bin(10))
print(oct(10))
print(hex(10))
# Out:
# 0b1010
# 0o12
# 0xa

# %% [markdown]
# **11. id**

# %%
# used to find memory address
a = 5
id(a)
# Out:
# 140716980610296

# %% [markdown]
# **12. ord**

# %%
# to find ascii code
char = input("Enter a character: ")
ord(char)
# Out:
# 32

# %% [markdown]
# **13. len**

# %%
# to calculate : iterable length
string = input("Enter your string: ")
print("string length: ",len(string))

print("list length: ",len([1,2,3,4]))
# Out:
# string length:  1
# list length:  4

# %% [markdown]
# **14. sum**

# %%
print(sum(range(1,10)))

list = [1,2,3,4,5,6,7]
print(sum(list))
# Out:
# 45
# 28

# %% [markdown]
# **15. help**

# %%
# to see documentation
help("id")
# Out:
# Help on built-in function id in module builtins:
#
# id(obj, /)
#     Return the identity of an object.
#
#     This is guaranteed to be unique among simultaneously existing objects.
#     (CPython uses the object's memory address.)
