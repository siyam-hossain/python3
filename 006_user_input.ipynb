# %%
input("Enter your name: ")
# Out:
# 'siyam'

# %%
firstNum = int(input("Enter 1st Number: "))
secondNum = int(input("Enter 2nd Number: "))

sum = firstNum+secondNum
print("firstNum + secondNum = ",sum)
# Out:
# firstNum + secondNum =  23

# %%
# concatenation
fName = "siyam"
lName = "Hossain"
fullName = fName + lName
print(fullName)
# Out:
# siyamHossain

# %% [markdown]
# **Type**

# %%
type(6)
# Out:
# int

# %%
type(4.5)
# Out:
# float

# %%
type("siyam")
# Out:
# str

# %%
type([1,2,3,4,5])
# Out:
# list
