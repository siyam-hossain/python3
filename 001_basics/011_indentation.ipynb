# %% [markdown]
# ### **Indentation**
#
# > 1. Python doesn't use { }, ; to write block
# > 2. It use (:)
# > 3. Use the 1 Tab space to start block

# %%
name = "xyz"
if name == "xyz":
    print("line1") 
    print("line2")
    
    if 123 == 123:
        print("123")
    else:
        print("I don't know")
else:
    print("line3")
# Out:
# line1
# line2
# 123
