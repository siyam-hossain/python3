# %%
print("Hello world")
# Out:
# Hello world

# %%
print(6)
# Out:
# 6

# %%
print(False)
# Out:
# False

# %%
print("Bangladesh","Nepal","Japan")
# Out:
# Bangladesh Nepal Japan

# %%
print("Bangladesh",65,True)
# Out:
# Bangladesh 65 True

# %%
print("Bangladesh","Nepal","Japan",sep="/")
# Out:
# Bangladesh/Nepal/Japan

# %%
print("Bangladesh","Nepal","Japan",sep="|")
# Out:
# Bangladesh|Nepal|Japan

# %%
print("Bangladesh","Nepal","Japan",sep="-")
# Out:
# Bangladesh-Nepal-Japan

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
# same line
print("Hello",end=' ')
print("World")
# Out:
# Hello World
