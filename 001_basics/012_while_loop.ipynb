# %% [markdown]
# ## **Loops**
# ***
# > 1. while loop
# > 2. for loop

# %%
number = int(input("Enter a number: "))
i = 1
while i<11:
    print(number,"x",i," : ",number*i)
    i += 1
# Out:
# 24 x 1  :  24
# 24 x 2  :  48
# 24 x 3  :  72
# 24 x 4  :  96
# 24 x 5  :  120
# 24 x 6  :  144
# 24 x 7  :  168
# 24 x 8  :  192
# 24 x 9  :  216
# 24 x 10  :  240

# %%
number = int(input("Enter a number: "))
i = 10
while i>0:
    print(number,"x",i," : ",number*i)
    i -= 1
# Out:
# 24 x 10  :  240
# 24 x 9  :  216
# 24 x 8  :  192
# 24 x 7  :  168
# 24 x 6  :  144
# 24 x 5  :  120
# 24 x 4  :  96
# 24 x 3  :  72
# 24 x 2  :  48
# 24 x 1  :  24
