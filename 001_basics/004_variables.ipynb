# %%
# variable declaration

# %%
name = 'Siyam Hossain'

# %%
print(name)
# Out:
# Siyam Hossain

# %%
# no varible declaration need

# %%
# Dynamic typing: python: no need to specify the variable type
# Static typing: in clang, c++

# %%
print(name)
# Out:
# Siyam Hossain

# %%
name = 4
print(name)
# Out:
# 4

# %%
name = True
print(name)
# Out:
# True

# %%
# Dynamic Binding: One variable can store multiple data types

# %%
# static binding:
# once you declare variable,
# the variable data type never change
# similar to c lang

# %%
# Special syntax
a=5; b=6; c=65
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 65

# %%
a,b,c = 1,65,8
print(a)
print(b)
print(c)
# Out:
# 1
# 65
# 8

# %%
a = b = c = 65
print(a,b,c)
# Out:
# 65 65 65
