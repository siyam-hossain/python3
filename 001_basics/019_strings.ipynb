# %% [markdown]
# ## **String**

# %% [markdown]
# Strings are sequence of characters
# In python specifically, strings are a sequence of unicode caracters
#
# + Creating strings
# + Accessing strings
# + Adding chars strings
# + Deleting strings
# + Operations strings
# + strings functions

# %% [markdown]
# **Creating strings**

# %%
c = "hello"
print(c)
# Out:
# hello

# %%
c = 'world'
print(c)
# Out:
# world

# %%
"what's your name"
# Out:
# "what's your name"

# %%
c = '''A man best friend is, his ten finguers'''
print(c)
# multiline string
c = """A man best friend is, his ten finguers"""
print(c)
# Out:
# A man best friend is, his ten finguers
# A man best friend is, his ten finguers

# %%
c = str("hello world")
c
# Out:
# 'hello world'
