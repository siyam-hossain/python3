# %% [markdown]
# **Python is a case sensitive programming language**

# %% [markdown]
# ### **Keyword**
# ###### In programming, a keyword is a word that is reserved by a program because the word has a special meaning. Keywords can be commands or parameters. Every programming language has a set of keywords that cannnot be used as variable

# %%
# python has 33 keywords
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### **Identifiers**

# %% [markdown]
# ###### A python identifier is a name used to identify a variable, function, class, module or other object

# %% [markdown]
# **Rules for setting Identifiers**
# >1. can only start with an alphabet or _
# >2. followed by 0 or more letter, _ and digits
# >3. keywords cannot be used as an identifiers

# %%
hey = "there"
_me = "here"
want_to_123 = "yes"

print(hey, _me, want_to_123)
# Out:
# there here yes

# %%
__ = "siyam hossain"
print(__)
# Out:
# siyam hossain
