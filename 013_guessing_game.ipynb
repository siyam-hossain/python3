# %% [markdown]
# ## **Guessing Game**

# %%
# using module
import random

# %%
random.randint(1,100)
# Out:
# 74

# %%
jackpot = random.randint(1,100)

guess = int(input("Enter a number: "))
attempts = 0

while guess != jackpot:
    if(guess < jackpot):
        print("guess higher")
    else:
        print("guess lower")
    guess = int(input("Guess again: "))
    attempts += 1

print("Right answer, need ",attempts, "attempts")
# Out:
# guess lower
# guess higher
# guess higher
# guess lower
# guess lower
# guess higher
# Right answer, need  7 attempts
