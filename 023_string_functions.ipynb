# %% [markdown]
# ## **Common Functions**
#
# + len
# + max
# + min
# + sorted

# %%
c = "Chandpur"
len(c)
# Out:
# 8

# %%
# interms of ascii value
max(c)
# Out:
# 'u'

# %%
# interms of ascii value
min(c)
# Out:
# 'C'

# %%
# interms of ascii value
# output in list format
# assending order
sorted(c)
# Out:
# ['C', 'a', 'd', 'h', 'n', 'p', 'r', 'u']

# %%
sorted(c, reverse=True)
# Out:
# ['u', 'r', 'p', 'n', 'h', 'd', 'a', 'C']

# %% [markdown]
# **1. Capitalize/Title/Upper/Lower/Swapcase**

# %%
name = "siyam hossain"
name
# Out:
# 'siyam hossain'

# %%
name.capitalize()
# Out:
# 'Siyam hossain'

# %%
name
# Out:
# 'siyam hossain'

# %%
name.title()
# Out:
# 'Siyam Hossain'

# %%
name.upper()
# Out:
# 'SIYAM HOSSAIN'

# %%
name.lower()
# Out:
# 'siyam hossain'

# %%
# convert lower thing to upper
# convert uppper thing to lower
"Hey, there. How Are You?".swapcase()
# Out:
# 'hEY, THERE. hOW aRE yOU?'

# %% [markdown]
# **2. count**

# %%
"it is raining".count("i")
# Out:
# 4

# %%
"it is raining".count("is")
# Out:
# 1

# %%
"it is raining".count("in")
# Out:
# 2

# %%
"it is raining".count("p")
# Out:
# 0

# %% [markdown]
# **3. find/index**

# %%
"it is raining".find("i")
# Out:
# 0

# %%
"it is raining".find("g")
# Out:
# 12

# %%
"it is raining".find("raining")
#0123456
# Out:
# 6

# %%
"it is raining".find("hello")
# Out:
# -1

# %%
# index
"it is raining".index("raining")
# Out:
# 6

# %%
"it is raining".index("p")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 "it is raining".index("p")
#
# ValueError: substring not found

# %% [markdown]
# **4. endswith/startwith**

# %%
"it is raining".endswith("ing")
# Out:
# True

# %%
"it is raining".endswith("gy")
# Out:
# False

# %%
"it is raining".startswith("ing")
# Out:
# False

# %%
"it is raining".startswith("it")
# Out:
# True

# %% [markdown]
# **5. format**

# %%
"hi, there. this is {} and i am {}".format("siyam",21)
# Out:
# 'hi, there. this is siyam and i am 21'

# %%
#                                              0      1
"hi, there. this is {1} and i am {0}".format("siyam",21)
# Out:
# 'hi, there. this is 21 and i am siyam'

# %%
"hi, there. this is {name} and i am {age}".format(name="siyam",age=21)
# Out:
# 'hi, there. this is siyam and i am 21'

# %%
"hi, there. this is {name} and i am {age}".format(age="siyam",name=21)
# Out:
# 'hi, there. this is 21 and i am siyam'

# %% [markdown]
# **6. isalnum/ isalpha/ isdecimal/ isdigit/ isidentifier**

# %%
"FLAT20".isalnum()
# Out:
# True

# %%
"siyam420&".isalnum()
# Out:
# False

# %%
"siyam".isalpha()
# Out:
# True

# %%
"siyam123".isalpha()
# Out:
# False

# %%
"siyam123".isdigit()
# Out:
# False

# %%
"123".isdigit()
# Out:
# True

# %%
"hello world".isidentifier()
# Out:
# False

# %%
"hello_world".isidentifier()
# Out:
# True

# %% [markdown]
# **7. split**

# %%
"I love my country".split()
# Out:
# ['I', 'love', 'my', 'country']

# %%
"I love my country".split("love")
# Out:
# ['I ', ' my country']

# %%
"my name is siyam hossain. what is your name".split('s')
# Out:
# ['my name i', ' ', 'iyam ho', '', 'ain. what i', ' your name']

# %%
"my name is siyam hossain. what is your name".split('z')
# Out:
# ['my name is siyam hossain. what is your name']

# %% [markdown]
# **8. join**

# %%
"s".join(['my name i', ' ', 'iyam ho', '', 'ain. what i', ' your name'])
# Out:
# 'my name is siyam hossain. what is your name'

# %%
"/".join(['my name i', ' ', 'iyam ho', '', 'ain. what i', ' your name'])
# Out:
# 'my name i/ /iyam ho//ain. what i/ your name'

# %%
"-".join(['my name i', ' ', 'iyam ho', '', 'ain. what i', ' your name'])
# Out:
# 'my name i- -iyam ho--ain. what i- your name'

# %% [markdown]
# **9. replace**

# %%
"hey there this is hassan".replace("hassan", "siyam")
# Out:
# 'hey there this is siyam'

# %% [markdown]
# **10. strip**

# %%
name = "              siyam                       "
name
# Out:
# '              siyam                       '

# %%
"hi" + name
# Out:
# 'hi              siyam                       '

# %%
name.strip()
# Out:
# 'siyam'
